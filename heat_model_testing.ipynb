# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import detrend
from heat import heat

# %%
tmin = 0
tmax = 100
nt = 199
zmax = 200
nz = 99
dTdz = 0.02

t_surf = np.linspace(0,1,nt)

U,t,z = heat(t_surf,
             tmax = tmax,
             tmin = tmin,
             zmax = zmax,
             dTdz = dTdz,
             nz = nz,
             nt = nt,
             accumulation = 0)

# %%
fig, ax = plt.subplots()
ax.plot(U[:,-1],-z)
